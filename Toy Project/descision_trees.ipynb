# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('C:\Users\srida\Desktop\test101\test101\Untitled Folder\simulated_data.csv')
# Out:
#   File "<ipython-input-3-c8eee0cc5473>", line 1
#     df = pd.read_csv('C:\Users\srida\Desktop\test101\test101\Untitled Folder\simulated_data.csv')
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.head()
# Out:
#           x         y
# 0  0.000000  0.086260
# 1  0.063467  0.881165
# 2  0.126933  0.145261
# 3  0.190400 -0.252824
# 4  0.253866 -0.320448

# %%
def fit_and_plot_model(df, model):
    #splitting input features and target variable
    features = df.drop('y',axis = 1)
    target = df.y
    #fitting the model
    model.fit(features, target)
    #plotting the graphs
    plt.scatter(df.x , df.y)#scatter plot for the training points
    plt.plot(df.x,model.predict(features),'m--')#predicted linear model
    
    plt.show()
    #returning the model
    return model

# %%
def fit_and_plot_polynomial_model(df,model,poly =1):
    if poly == 1:
        return fit_and_plot_model(df,model)
    elif poly>1:
        df_copy = df.copy()
        for i in range(2,poly+1):
            df_copy['x'+str(i)]=np.power(df.x,i)
        return fit_and_plot_model(df_copy,model)
    else:
        pass

# %%
model = fit_and_plot_model(df,DecisionTreeRegressor())

# %%
from sklearn.tree import export_graphviz

# %%
from graphviz import Source
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-4beb1b17c5b2> in <module>
# ----> 1 from graphviz import Source
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
import graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f7133d3517ab> in <module>
# ----> 1 import graphviz
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
from Ipython.display import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-adb44ecae120> in <module>
# ----> 1 from Ipython.display import Image
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
def plot_and_save_decision_tree(model, out_filename):
    graph = Source(export_graphviz(model,out_file=None))
    tree_png = graph.pipe(format = 'png')
    with open(outfilename, 'wb') as f:
        f.write(tree_png)
    return Image(tree_png)

# %%
plot_and_save_decision_tree(model, 'new1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-42f86502844b> in <module>
# ----> 1 plot_and_save_decision_tree(model, 'new1')
#
# <ipython-input-18-ac85068712e8> in plot_and_save_decision_tree(model, out_filename)
#       1 def plot_and_save_decision_tree(model, out_filename):
# ----> 2     graph = Source(export_graphviz(model,out_file=None))
#       3     tree_png = graph.pipe(format = 'png')
#       4     with open(outfilename, 'wb') as f:
#       5         f.write(tree_png)
#
# NameError: name 'Source' is not defined
